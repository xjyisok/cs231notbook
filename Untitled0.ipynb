# %% [markdown]
# <a href="https://colab.research.google.com/github/xjyisok/cs231notbook/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/yolov5/yolov5.zip -d /content/drive/MyDrive/yolov5
# Out:
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_656.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_657.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_658.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_659.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_66.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_660.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_661.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_662.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_663.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_664.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_665.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_666.txt
#   inflating: /content/drive/MyDrive/yolov5/mydata/label/train/9_667.txt
# ...
